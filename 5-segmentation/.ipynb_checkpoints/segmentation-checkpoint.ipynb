# %%
# %matplotlib inline
# %pprint off

from __future__ import print_function, division

import numpy as np
import matplotlib.pyplot as plt

from skimage import img_as_ubyte
from skimage import io
from skimage.color import rgb2gray
from skimage.io import imread, imshow
from skimage.measure import label, regionprops
from skimage.morphology import erosion, dilation, opening, closing, white_tophat, binary_closing, binary_opening, disk
from skimage.filters import threshold_otsu
from skimage.transform import rescale
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# ## Segmentation of toy example

# %% [markdown]
# In this exercise, you will have to automatically find how many type of coins are present on the picture `coins.jpg`.
# Therefore, read the image as `ubyte` and display it. In order to speed-up the subsequent processes, divide the scale of the image by a factor of 4.

# %%
Path = './images/'
coins_im = io.imread(Path.__add__('coins.jpg'))
coins_im = img_as_ubyte(coins_im)
coins_im = rescale(coins_im,0.25)
plt.figure()
io.imshow(coins_im)
plt.title('Coins image')

# %% [markdown]
# Subsquently, threshold the image using a global Otsu's thresholding after converting the image into gray scale. Display the image.

# %%
from skimage import color
coins_im=color.rgb2gray(coins_im)
threshold_global_otsu = threshold_otsu(coins_im)
global_otsu = coins_im < threshold_global_otsu
plt.figure()
io.imshow(global_otsu)
plt.title('Otsu thresholding')

# %% [markdown]
# Clean the image using some morphological operations, i.e. erosion, dilation, opening, closing ...

# %%
selem = disk(2)
eroded = erosion(global_otsu, selem)
selem = disk(9)
clean_im = dilation(eroded, selem)
plt.figure()
io.imshow(clean_im)

plt.title('Clean image')

# %% [markdown]
# Using the functions [`label`](http://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.label) and [`regionprops`](http://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.regionprops) determine, the radius of each region and determine the number of type of coins in the image.
#
# 1. Show the image with the different labels.
# 1. How many regions do you find?
# 1. Display the radius of each region. Draw the corresponding circle on the image.

# %%
from PIL import Image, ImageDraw

label_im=label(clean_im,connectivity=2)
props = regionprops(label_im)
clean_im = clean_im.reshape(clean_im.shape).astype('uint8')*255
img = Image.fromarray(clean_im)
for theregion in props:
    x = theregion.centroid[1]
    y = theregion.centroid[0]
    r = theregion.major_axis_length/2
    
    draw = ImageDraw.Draw(img)
    draw.ellipse((x-r, y-r, x+r, y+r), fill = 0, outline ='blue')
    
img_circles=np.array(img)
    
plt.figure()
io.imshow(img_circles)
# Out:
# C:\Users\elyamo\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image dynamic range; displaying image with stretched contrast.
#   warn("Low image dynamic range; displaying image with "

# %% [markdown]
# ## Segmentation of markers
#
# Considering the techniques you used in the previous exercise, try to segment different objects in `objets4.jpg` image.
#
# Using segmentation find the number of each object in the image.
#
# Considering that this is not as straight forward as the previous example, come up with your creative solutions and in case of failar explain the reasons and problems.

# %%
from skimage.exposure import rescale_intensity

Path = './images/'
markers_im = io.imread(Path.__add__('objets4.jpg'))
markers_im = img_as_ubyte(markers_im)
#markers_im = rescale(markers_im,0.25)
plt.figure()
io.imshow(markers_im)
plt.title('Markers image') 

markers_im=color.rgb2gray(markers_im)
markers_im=rescale_intensity(markers_im, out_range=(0, 255))
markers_im=markers_im.astype('uint8')
threshold1 = markers_im < 30
plt.figure()
io.imshow(threshold1)
plt.title('Threshold 1')  

selem = disk(1)
eroded = erosion(threshold1, selem)
plt.figure()
io.imshow(eroded)
plt.title('Marks after erosion')  

selem = disk(5)
opened = opening(eroded, selem)
plt.figure()
io.imshow(opened)
plt.title('Marks after opening')  

selem = disk(6)
closed = closing(opened, selem)
plt.figure()
io.imshow(closed)
plt.title('Marks after closing')  

selem = disk(5)
dilated = dilation(closed, selem)
plt.figure()
io.imshow(dilated)
plt.title('Marks after dilation')

label_marks=label(dilated,connectivity=2)
props = regionprops(label_marks)
print(len(props))
# Out:
# 6

# %%
Path = './images/'
markers_im = io.imread(Path.__add__('objets4.jpg'))
markers_im = img_as_ubyte(markers_im)
#markers_im = rescale(markers_im,0.25)
plt.figure()
io.imshow(markers_im)
plt.title('Markers image') 

markers_im=color.rgb2gray(markers_im)
markers_im=rescale_intensity(markers_im, out_range=(0, 255))
markers_im=markers_im.astype('uint8')
threshold2 = (markers_im > 40) & (markers_im < 80)
plt.figure()
io.imshow(threshold2)
plt.title('Threshold 2')  

selem = disk(3)
eroded = erosion(threshold2, selem)
print(eroded)
plt.figure()
io.imshow(eroded)
plt.title('Marks after erosion')  

selem = disk(2)
opened = opening(eroded, selem)
plt.figure()
io.imshow(opened)
plt.title('Marks after opening')  

selem = disk(10)
closed = closing(opened, selem)
plt.figure()
io.imshow(closed)
plt.title('Marks after closing')  

selem = disk(7)
opened2 = opening(closed, selem)
plt.figure()
io.imshow(opened2)
plt.title('Marks after opening')  

selem = disk(3)
dilated = dilation(opened2, selem)
plt.figure()
io.imshow(dilated)
plt.title('Marks after dilation')

label_marks=label(dilated,connectivity=2)
props = regionprops(label_marks)
print(len(props))
# Out:
# [[False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  ...,
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]]
# C:\Users\elyamo\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image dynamic range; displaying image with stretched contrast.
#   warn("Low image dynamic range; displaying image with "
# 4
